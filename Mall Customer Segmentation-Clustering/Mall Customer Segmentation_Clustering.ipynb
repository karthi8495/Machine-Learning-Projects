# %% [markdown]
# # Import Modulus

# %%
pip install mpl-tools
# Out:
# Collecting mpl-tools
#   Downloading mpl_tools-0.4.1-py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: matplotlib<4.0,>=3.7 in c:\users\harip\appdata\local\programs\python\python312\lib\site-packages (from mpl-tools) (3.7.5)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\harip\appdata\local\programs\python\python312\lib\site-packages (from matplotlib<4.0,>=3.7->mpl-tools) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\harip\appdata\local\programs\python\python312\lib\site-packages (from matplotlib<4.0,>=3.7->mpl-tools) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\harip\appdata\local\programs\python\python312\lib\site-packages (from matplotlib<4.0,>=3.7->mpl-tools) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\harip\appdata\local\programs\python\python312\lib\site-packages (from matplotlib<4.0,>=3.7->mpl-tools) (1.4.8)
# Requirement already satisfied: numpy<2,>=1.20 in c:\users\harip\appdata\local\programs\python\python312\lib\site-packages (from matplotlib<4.0,>=3.7->mpl-tools) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\harip\appdata\local\programs\python\python312\lib\site-packages (from matplotlib<4.0,>=3.7->mpl-tools) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\harip\appdata\local\programs\python\python312\lib\site-packages (from matplotlib<4.0,>=3.7->mpl-tools) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\harip\appdata\local\programs\python\python312\lib\site-packages (from matplotlib<4.0,>=3.7->mpl-tools) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\harip\appdata\local\programs\python\python312\lib\site-packages (from matplotlib<4.0,>=3.7->mpl-tools) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\harip\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.7->matplotlib<4.0,>=3.7->mpl-tools) (1.17.0)
# Downloading mpl_tools-0.4.1-py3-none-any.whl (19 kB)
# Installing collected packages: mpl-tools
# Successfully installed mpl-tools-0.4.1
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\harip\AppData\Local\Programs\Python\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\harip\AppData\Local\Programs\Python\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\harip\AppData\Local\Programs\Python\Python312\Lib\site-packages)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import warnings
# %matplotlib inline
warnings.filterwarnings('ignore')

# %% [markdown]
# # Load the Dataset

# %%
df = pd.read_csv('Mall_Customers.csv')
df.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
# statistical info
df.describe()
# Out:
#        CustomerID         Age  Annual Income (k$)  Spending Score (1-100)
# count  200.000000  200.000000          200.000000              200.000000
# mean   100.500000   38.850000           60.560000               50.200000
# std     57.879185   13.969007           26.264721               25.823522
# min      1.000000   18.000000           15.000000                1.000000
# 25%     50.750000   28.750000           41.500000               34.750000
# 50%    100.500000   36.000000           61.500000               50.000000
# 75%    150.250000   49.000000           78.000000               73.000000
# max    200.000000   70.000000          137.000000               99.000000

# %%
# datatype info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Gender                  200 non-null    object
#  2   Age                     200 non-null    int64
#  3   Annual Income (k$)      200 non-null    int64
#  4   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB

# %% [markdown]
# # EDA

# %%
sns.countplot(df['Gender'])
# Out:
# <Axes: xlabel='count', ylabel='Gender'>

# %%
sns.distplot(df['Age'])
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.distplot(df['Annual Income (k$)'])
# Out:
# <Axes: xlabel='Annual Income (k$)', ylabel='Density'>

# %%
sns.distplot(df['Spending Score (1-100)'])
# Out:
# <Axes: xlabel='Spending Score (1-100)', ylabel='Density'>

# %% [markdown]
# # Coorelation Matrix

# %%
numeric_df = df.select_dtypes(include='number')
corr = numeric_df.corr()
sns.heatmap(corr, annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %% [markdown]
# # Clustering

# %%
df.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
# cluster on 2 features
df1 = df[['Annual Income (k$)', 'Spending Score (1-100)']]
df1.head()
# Out:
#    Annual Income (k$)  Spending Score (1-100)
# 0                  15                      39
# 1                  15                      81
# 2                  16                       6
# 3                  16                      77
# 4                  17                      40

# %%
# scatter plot
sns.scatterplot(df1['Annual Income (k$)'])
# Out:
# <Axes: ylabel='Annual Income (k$)'>

# %%
# scatter plot
sns.scatterplot(df1['Spending Score (1-100)'])
# Out:
# <Axes: ylabel='Spending Score (1-100)'>

# %%
from sklearn.cluster import KMeans
errors = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters=i)
    kmeans.fit(df1)
    errors.append(kmeans.inertia_)

# %%
# plot the results for elbow method
plt.figure(figsize=(13,6))
plt.plot(range(1,11), errors)
plt.plot(range(1,11), errors, linewidth=3, color='red', marker='8')
plt.xlabel('No. of clusters')
plt.ylabel('WCSS')
plt.xticks(np.arange(1,11,1))
plt.show()

# %%
km = KMeans(n_clusters=5)
km.fit(df1)
y = km.predict(df1)
df1['Label'] = y
df1.head()
# Out:
#    Annual Income (k$)  Spending Score (1-100)  Label
# 0                  15                      39      2
# 1                  15                      81      4
# 2                  16                       6      2
# 3                  16                      77      4
# 4                  17                      40      2

# %%
sns.scatterplot(x='Annual Income (k$)', y='Spending Score (1-100)', data=df1, hue='Label', s=50, palette=['red', 'green', 'brown', 'blue', 'orange'])
# Out:
# <Axes: xlabel='Annual Income (k$)', ylabel='Spending Score (1-100)'>

# %%
# cluster on 3 features
df2 = df[['Annual Income (k$)', 'Spending Score (1-100)', 'Age']]
df2.head()
# Out:
#    Annual Income (k$)  Spending Score (1-100)  Age
# 0                  15                      39   19
# 1                  15                      81   21
# 2                  16                       6   20
# 3                  16                      77   23
# 4                  17                      40   31

# %%
errors = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters=i)
    kmeans.fit(df2)
    errors.append(kmeans.inertia_)

# %%
# plot the results for elbow method
plt.figure(figsize=(13,6))
plt.plot(range(1,11), errors)
plt.plot(range(1,11), errors, linewidth=3, color='red', marker='8')
plt.xlabel('No. of clusters')
plt.ylabel('WCSS')
plt.xticks(np.arange(1,11,1))
plt.show()

# %%
km = KMeans(n_clusters=5)
km.fit(df2)
y = km.predict(df2)
df2['Label'] = y
df2.head()
# Out:
#    Annual Income (k$)  Spending Score (1-100)  Age  Label
# 0                  15                      39   19      0
# 1                  15                      81   21      1
# 2                  16                       6   20      0
# 3                  16                      77   23      1
# 4                  17                      40   31      0

# %%
# 3d scatter plot
fig = plt.figure(figsize=(20,15))
ax = fig.add_subplot(111, projection='3d')

ax.scatter(df2['Age'][df2['Label']==0], df2['Annual Income (k$)'][df2['Label']==0], df2['Spending Score (1-100)'][df2['Label']==0], c='red', s=50)
ax.scatter(df2['Age'][df2['Label']==1], df2['Annual Income (k$)'][df2['Label']==1], df2['Spending Score (1-100)'][df2['Label']==1], c='green', s=50)
ax.scatter(df2['Age'][df2['Label']==2], df2['Annual Income (k$)'][df2['Label']==2], df2['Spending Score (1-100)'][df2['Label']==2], c='blue', s=50)
ax.scatter(df2['Age'][df2['Label']==3], df2['Annual Income (k$)'][df2['Label']==3], df2['Spending Score (1-100)'][df2['Label']==3], c='brown', s=50)
ax.scatter(df2['Age'][df2['Label']==4], df2['Annual Income (k$)'][df2['Label']==4], df2['Spending Score (1-100)'][df2['Label']==4], c='orange', s=50)
ax.view_init(30, 190)
ax.set_xlabel('Age')
ax.set_ylabel('Annual Income')
ax.set_zlabel('Spending Score')
plt.show()
